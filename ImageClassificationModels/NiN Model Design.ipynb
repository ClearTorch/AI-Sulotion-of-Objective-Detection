# %% [markdown]
# # NiN模型
# 网络中的网络（NiN）。它提出了另外一个思路，即串联多个由卷积层和“全连接”层构成的小网络来构建一个深层网络。
# ## NiN块
# 卷积层的输入和输出通常是四维数组（样本，通道，高，宽），而全连接层的输入和输出则通常是二维数组（样本，特征）。如果想在全连接层后再接上卷积层，则需要将全连接层的输出变换为四维。$1\times 1$卷积层。它可以看成全连接层，其中空间维度（高和宽）上的每个元素相当于样本，通道相当于特征。因此，NiN使用$1\times 1$卷积层来替代全连接层，从而使空间信息能够自然传递到后面的层中去。
# NiN块是NiN中的基础块。它由一个卷积层加两个充当全连接层的$1\times 1$卷积层串联而成。其中第一个卷积层的超参数可以自行设置，而第二和第三个卷积层的超参数一般是固定的。
# ## NiN模型
# NiN是在AlexNet问世不久后提出的。它们的卷积层设定有类似之处。NiN使用卷积窗口形状分别为$11\times 11$、$5\times 5$和$3\times 3$的卷积层，相应的输出通道数也与AlexNet中的一致。每个NiN块后接一个步幅为2、窗口形状为$3\times 3$的最大池化层。
#
# 除使用NiN块以外，NiN还有一个设计与AlexNet显著不同：NiN去掉了AlexNet最后的3个全连接层，取而代之地，NiN使用了输出通道数等于标签类别数的NiN块，然后使用全局平均池化层对每个通道中所有元素求平均并直接用于分类。这里的全局平均池化层即窗口形状等于输入空间维形状的平均池化层。NiN的这个设计的好处是可以显著减小模型参数尺寸，从而缓解过拟合。然而，该设计有时会造成获得有效模型的训练时间的增加。

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
import datetime
print(tf.__version__)

for gpu in tf.config.experimental.list_physical_devices('GPU'):
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2.2.0

# %%
class NiN:
    def __init__(self):
        fashion_mnist = tf.keras.datasets.fashion_mnist
        (self.train_images, self.train_labels), (self.test_images, self.test_labels) = fashion_mnist.load_data()
        self.train_images = np.expand_dims(self.train_images.astype(np.float32)/255.0,axis=-1)
        self.test_images = np.expand_dims(self.test_images.astype(np.float32)/255.0,axis=-1)
        self.train_labels = self.train_labels.astype(np.int32)
        self.test_labels = self.test_labels.astype(np.int32)
        self.num_train, self.num_test = self.train_images.shape[0], self.test_images.shape[0]

    def nin_block(self, num_channels, kernel_size, strides, padding):
        blk = models.Sequential()
        blk.add(tf.keras.layers.Conv2D(num_channels, kernel_size,
                                       strides=strides, padding=padding, activation='relu')) 
        blk.add(tf.keras.layers.Conv2D(num_channels, kernel_size=1,activation='relu')) 
        blk.add(tf.keras.layers.Conv2D(num_channels, kernel_size=1,activation='relu'))    
        return blk
    
    def build_nin(self):
        tf.keras.backend.clear_session()
        net = models.Sequential()
        net.add(self.nin_block(96, kernel_size=11, strides=4, padding='valid'))
        net.add(layers.MaxPool2D(pool_size=3, strides=2))
        net.add(self.nin_block(256, kernel_size=5, strides=1, padding='same'))
        net.add(layers.MaxPool2D(pool_size=3, strides=2))
        net.add(self.nin_block(384, kernel_size=3, strides=1, padding='same'))
        net.add(layers.MaxPool2D(pool_size=3, strides=2))
        net.add(layers.Dropout(0.5))
        net.add(self.nin_block(10, kernel_size=3, strides=1, padding='same'))
        net.add(layers.GlobalAveragePooling2D())
        net.add(layers.Flatten())
        net.compile(optimizer= optimizers.Adam(lr=1e-7),
                    loss='sparse_categorical_crossentropy',metrics=['accuracy'])
        return net
    
    def get_batch_train(self, batch_size):
        index = np.random.randint(0, np.shape(self.train_images)[0], batch_size)
        #need to resize images to (224,224)
        resized_images = tf.image.resize_with_pad(self.train_images[index],224,224,)
        return resized_images.numpy(), self.train_labels[index]

    def get_batch_test(self, batch_size):
        index = np.random.randint(0, np.shape(self.test_images)[0], batch_size)
        #need to resize images to (224,224)
        resized_images = tf.image.resize_with_pad(self.test_images[index],224,224,)
        return resized_images.numpy(), self.test_labels[index]
    
    def see_output_shape(self, net):
        X = tf.random.uniform((1,224,224,1))
        for blk in net.layers:
            X = blk(X)
            print(blk.name, 'output shape:\t', X.shape)
            
    def train_nin(self, net, epoch, batch_size = 128):
        #net.load_weights("./ModelTrain/nin_weights.h5")
        
        # %load_ext tensorboard
        log_dir = './log/nin1/' + datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
        tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq=1)
        num_iter = self.num_train//batch_size
        with tf.device('/gpu:0'):
            for e in range(epoch):
                for n in range(num_iter):
                    x_batch, y_batch = self.get_batch_train(batch_size)
                    hitory = net.fit(x_batch, y_batch, callbacks=[tensorboard_callback])
                    if n%20 == 0:
                        net.save_weights("./ModelTrain/nin_weights.h5")
        # %tensorboard --logdir log/min1
        return net

# %%
nin = NiN()
net = nin.build_nin()
net = nin.train_nin(net,5)
# Out:
# 4/4 [==============================] - 1s 148ms/step - loss: 2.7670 - accuracy: 0.0703
# 4/4 [==============================] - 1s 142ms/step - loss: 2.7378 - accuracy: 0.0859
# 4/4 [==============================] - 1s 130ms/step - loss: 2.7925 - accuracy: 0.0625
# 4/4 [==============================] - 1s 137ms/step - loss: 2.7040 - accuracy: 0.0703
# 4/4 [==============================] - 1s 144ms/step - loss: 2.7659 - accuracy: 0.0234
# 2/4 [==============>...............] - ETA: 0s - loss: 2.6629 - accuracy: 0.0469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.100145). Check your callbacks.
# 4/4 [==============================] - 1s 139ms/step - loss: 2.7996 - accuracy: 0.0391
# 4/4 [==============================] - 1s 129ms/step - loss: 2.7640 - accuracy: 0.0312
# 2/4 [==============>...............] - ETA: 0s - loss: 2.9111 - accuracy: 0.0625WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.106484). Check your callbacks.
# 4/4 [==============================] - 1s 141ms/step - loss: 2.8825 - accuracy: 0.0625
# 4/4 [==============================] - 1s 130ms/step - loss: 2.5956 - accuracy: 0.0625
# 4/4 [==============================] - 1s 132ms/step - loss: 2.5128 - accuracy: 0.0547
# 2/4 [==============>...............] - ETA: 0s - loss: 2.5552 - accuracy: 0.0469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.115654). Check your callbacks.
# 4/4 [==============================] - 1s 152ms/step - loss: 2.6109 - accuracy: 0.0625
# 4/4 [==============================] - 0s 123ms/step - loss: 2.6611 - accuracy: 0.0859
# 4/4 [==============================] - 0s 115ms/step - loss: 2.6727 - accuracy: 0.0781
# 4/4 [==============================] - 1s 133ms/step - loss: 2.9626 - accuracy: 0.0859
# 4/4 [==============================] - 1s 134ms/step - loss: 2.6514 - accuracy: 0.0781
# 2/4 [==============>...............] - ETA: 0s - loss: 2.8334 - accuracy: 0.0312WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0
- accuracy: 0.0625WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.108386). Check your callbacks.
# 4/4 [==============================] - 1s 155ms/step - loss: 2.6262 - accuracy: 0.0703
# 2/4 [==============>...............] - ETA: 0s - loss: 2.5475 - accuracy: 0.0781WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.132347). Check your callbacks.
# 4/4 [==============================] - 1s 161ms/step - loss: 2.7339 - accuracy: 0.0703
# 2/4 [==============>...............] - ETA: 0s - loss: 2.6165 - accuracy: 0.0469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.122531). Check your callbacks.
# 4/4 [==============================] - 1s 163ms/step - loss: 2.5173 - accuracy: 0.0781
# 2/4 [==============>...............] - ETA: 0s - loss: 2.9334 - accuracy: 0.0469    WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.153197). Check your callbacks.
# 4/4 [==============================] - 1s 167ms/step - loss: 2.8315 - accuracy: 0.0547
# 2/4 [==============>...............] - ETA: 0s - loss: 2.8288 - accuracy: 0.0938WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.121250). Check your callbacks.
# 4/4 [==============================] - 1s 140ms/step - loss: 2.7130 - accuracy: 0.0859
# 2/4 [==============>...............] - ETA: 0s - loss: 2.5159 - accuracy: 0.0625WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.127511). Check your callbacks.
# 4/4 [==============================] - 1s 154ms/step - loss: 2.6442 - accuracy: 0.0625
# 2/4 [==============>...............] - ETA: 0s - loss: 2.5222 - accuracy: 0.1094WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.110718). Check your callbacks.
# 4/4 [==============================] - 1s 166ms/step - loss: 2.4484 - accuracy: 0.1172
# 2/4 [==============>...............] - ETA: 0s - loss: 2.7968 - accuracy: 0.0469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.121697). Check your callbacks.
# 4/4 [==============================] - 1s 147ms/step - loss: 2.7737 - accuracy: 0.0391
# 2/4 [==============>...............] - ETA: 0s - loss: 2.5588 - accuracy: 0.0625WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.140184). Check your callbacks.
# 4/4 [==============================] - 1s 156ms/step - loss: 2.5795 - accuracy: 0.0859
# 4/4 [==============================] - 1s 145ms/step - loss: 2.5296 - accuracy: 0.0938
# 2/4 [==============>...............] - ETA: 0s - loss: 2.5752 - accuracy: 0.1250WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.161624). Check your callbacks.
# 4/4 [==============================] - 1s 166ms/step - loss: 2.4833 - accuracy: 0.1016
# 2/4 [==============>...............] - ETA: 0s - loss: 2.6312 - accuracy: 0.0781WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.115454). Check your callbacks.
# 4/4 [==============================] - 1s 196ms/step - loss: 2.6574 - accuracy: 0.0391
# 2/4 [==============>...............] - ETA: 0s - loss: 2.4495 - accuracy: 0.0781WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.143334). Check your callbacks.
# 4/4 [==============================] - 1s 178ms/step - loss: 2.4584 - accuracy: 0.0547
# 2/4 [==============>...............] - ETA: 0s - loss: 2.8013 - accuracy: 0.0625WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.119366). Check your callbacks.
# 4/4 [==============================] - 1s 161ms/step - loss: 2.5779 - accuracy: 0.0781
# 2/4 [==============>...............] - ETA: 0s - loss: 2.6040 - accuracy: 0.0781WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.114032). Check your callbacks.
# 4/4 [==============================] - 1s 152ms/step - loss: 2.6212 - accuracy: 0.0391
# 2/4 [==============>...............] - ETA: 0s - loss: 2.6895 - accuracy: 0.0781WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.145959). Check your callbacks.
# 4/4 [==============================] - 1s 159ms/step - loss: 2.6675 - accuracy: 0.0625
# 2/4 [==============>...............] - ETA: 0s - loss: 2.4813 - accuracy: 0.0469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.138019). Check your callbacks.
# 4/4 [==============================] - 1s 160ms/step - loss: 2.6946 - accuracy: 0.0625
# 2/4 [==============>...............] - ETA: 0s - loss: 2.6764 - accuracy: 0.0469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.135973). Check your callbacks.
# 4/4 [==============================] - 1s 169ms/step - loss: 2.7104 - accuracy: 0.0547
# 4/4 [==============================] - 1s 136ms/step - loss: 2.6252 - accuracy: 0.0859
# 2/4 [==============>...............] - ETA: 0s - loss: 2.7979 - accuracy: 0.0625WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0
- accuracy: 0.0625WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.120431). Check your callbacks.
# 4/4 [==============================] - 1s 138ms/step - loss: 2.5719 - accuracy: 0.0781
# 4/4 [==============================] - 0s 115ms/step - loss: 2.5658 - accuracy: 0.0625
# 4/4 [==============================] - 0s 111ms/step - loss: 2.4053 - accuracy: 0.0781
# 2/4 [==============>...............] - ETA: 0s - loss: 2.3196 - accuracy: 0.1094WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.100103). Check your callbacks.
# 4/4 [==============================] - 1s 127ms/step - loss: 2.4240 - accuracy: 0.0703
# 4/4 [==============================] - 0s 102ms/step - loss: 2.4957 - accuracy: 0.1016
# 4/4 [==============================] - 0s 112ms/step - loss: 2.4392 - accuracy: 0.0859
# ...
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5579 - accuracy: 0.4688WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.168664). Check your callbacks.
# 4/4 [==============================] - 1s 199ms/step - loss: 1.5942 - accuracy: 0.4297
# 2/4 [==============>...............] - ETA: 0s - loss: 1.4865 - accuracy: 0.5000WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.290890). Check your callbacks.
# 4/4 [==============================] - 1s 342ms/step - loss: 1.5908 - accuracy: 0.4688
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6141 - accuracy: 0.3281WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.254585). Check your callbacks.
# 4/4 [==============================] - 1s 249ms/step - loss: 1.6346 - accuracy: 0.3516
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5987 - accuracy: 0.3281WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.144296). Check your callbacks.
# 4/4 [==============================] - 1s 227ms/step - loss: 1.6058 - accuracy: 0.3984
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6366 - accuracy: 0.3125WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.315633). Check your callbacks.
# 4/4 [==============================] - 1s 310ms/step - loss: 1.6142 - accuracy: 0.3281
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5856 - accuracy: 0.4688WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.204534). Check your callbacks.
# 4/4 [==============================] - 1s 235ms/step - loss: 1.5516 - accuracy: 0.4922
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6880 - accuracy: 0.3906WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.194564). Check your callbacks.
# 4/4 [==============================] - 1s 236ms/step - loss: 1.6726 - accuracy: 0.3984
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6082 - accuracy: 0.2969WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.203010). Check your callbacks.
# 4/4 [==============================] - 1s 264ms/step - loss: 1.6341 - accuracy: 0.3594
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6753 - accuracy: 0.3906WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.202139). Check your callbacks.
# 4/4 [==============================] - 1s 250ms/step - loss: 1.6329 - accuracy: 0.4609
# 2/4 [==============>...............] - ETA: 0s - loss: 1.7084 - accuracy: 0.3438WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.136626). Check your callbacks.
# 4/4 [==============================] - 1s 204ms/step - loss: 1.6932 - accuracy: 0.3828
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6212 - accuracy: 0.3906WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.217631). Check your callbacks.
# 4/4 [==============================] - 1s 268ms/step - loss: 1.6327 - accuracy: 0.3828
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6222 - accuracy: 0.4219WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.256105). Check your callbacks.
# 4/4 [==============================] - 1s 345ms/step - loss: 1.6214 - accuracy: 0.3828
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5665 - accuracy: 0.4688WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.449414). Check your callbacks.
# 4/4 [==============================] - 2s 405ms/step - loss: 1.5794 - accuracy: 0.4297
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6588 - accuracy: 0.4688WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.239825). Check your callbacks.
# 4/4 [==============================] - 1s 256ms/step - loss: 1.6652 - accuracy: 0.3906
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6544 - accuracy: 0.4219WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.181425). Check your callbacks.
# 4/4 [==============================] - 1s 272ms/step - loss: 1.6051 - accuracy: 0.4141
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6453 - accuracy: 0.2969WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.182037). Check your callbacks.
# 4/4 [==============================] - 1s 278ms/step - loss: 1.6771 - accuracy: 0.3516
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5770 - accuracy: 0.3906WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.221200). Check your callbacks.
# 4/4 [==============================] - 1s 230ms/step - loss: 1.5439 - accuracy: 0.4531
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6589 - accuracy: 0.3906WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.203621). Check your callbacks.
# 4/4 [==============================] - 1s 252ms/step - loss: 1.6895 - accuracy: 0.3516
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5931 - accuracy: 0.4844WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.227726). Check your callbacks.
# 4/4 [==============================] - 1s 243ms/step - loss: 1.6048 - accuracy: 0.4531
# 2/4 [==============>...............] - ETA: 0s - loss: 1.7301 - accuracy: 0.4844WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.142509). Check your callbacks.
# 4/4 [==============================] - 1s 179ms/step - loss: 1.6923 - accuracy: 0.4375
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6429 - accuracy: 0.2969WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.150079). Check your callbacks.
# 4/4 [==============================] - 1s 223ms/step - loss: 1.6765 - accuracy: 0.3125
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6147 - accuracy: 0.4531WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.169514). Check your callbacks.
# 4/4 [==============================] - 1s 260ms/step - loss: 1.5943 - accuracy: 0.4844
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6070 - accuracy: 0.4219WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.151678). Check your callbacks.
# 4/4 [==============================] - 1s 248ms/step - loss: 1.6545 - accuracy: 0.4062
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6099 - accuracy: 0.3750WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.215017). Check your callbacks.
# 4/4 [==============================] - 1s 252ms/step - loss: 1.5821 - accuracy: 0.4297
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6986 - accuracy: 0.4062WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.217050). Check your callbacks.
# 4/4 [==============================] - 1s 255ms/step - loss: 1.6664 - accuracy: 0.4375
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6281 - accuracy: 0.3594WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.207999). Check your callbacks.
# 4/4 [==============================] - 1s 277ms/step - loss: 1.6056 - accuracy: 0.4062
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6006 - accuracy: 0.3438WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.232155). Check your callbacks.
# 4/4 [==============================] - 1s 271ms/step - loss: 1.5851 - accuracy: 0.4141
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6446 - accuracy: 0.4062WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.181888). Check your callbacks.
# 4/4 [==============================] - 1s 213ms/step - loss: 1.6144 - accuracy: 0.4297
# 2/4 [==============>...............] - ETA: 0s - loss: 1.7045 - accuracy: 0.3594WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.172910). Check your callbacks.
# 4/4 [==============================] - 1s 222ms/step - loss: 1.6805 - accuracy: 0.4062
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6389 - accuracy: 0.3594WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.232177). Check your callbacks.
# 4/4 [==============================] - 1s 255ms/step - loss: 1.6191 - accuracy: 0.3750
# 2/4 [==============>...............] - ETA: 0s - loss: 1.7302 - accuracy: 0.4219WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.174005). Check your callbacks.
# 4/4 [==============================] - 1s 198ms/step - loss: 1.6471 - accuracy: 0.4062
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6627 - accuracy: 0.3750WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.188804). Check your callbacks.
# 4/4 [==============================] - 1s 234ms/step - loss: 1.5595 - accuracy: 0.3828
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5958 - accuracy: 0.4219WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.165085). Check your callbacks.
# 4/4 [==============================] - 1s 236ms/step - loss: 1.5603 - accuracy: 0.4609
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5520 - accuracy: 0.4531WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.178558). Check your callbacks.
# 4/4 [==============================] - 1s 224ms/step - loss: 1.5366 - accuracy: 0.4297
# 2/4 [==============>...............] - ETA: 0s - loss: 1.7160 - accuracy: 0.3594WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.210302). Check your callbacks.
# 4/4 [==============================] - 1s 236ms/step - loss: 1.6939 - accuracy: 0.3672
# 2/4 [==============>...............] - ETA: 0s - loss: 1.4972 - accuracy: 0.5938WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.181217). Check your callbacks.
# 4/4 [==============================] - 1s 235ms/step - loss: 1.5516 - accuracy: 0.5391
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5366 - accuracy: 0.3594WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.176152). Check your callbacks.
# 4/4 [==============================] - 1s 235ms/step - loss: 1.5393 - accuracy: 0.3906
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6519 - accuracy: 0.3750WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.166173). Check your callbacks.
# 4/4 [==============================] - 1s 209ms/step - loss: 1.6158 - accuracy: 0.4062
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6015 - accuracy: 0.5000WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.257594). Check your callbacks.
# 4/4 [==============================] - 1s 248ms/step - loss: 1.6249 - accuracy: 0.4844
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5831 - accuracy: 0.4688WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.182549). Check your callbacks.
# 4/4 [==============================] - 1s 243ms/step - loss: 1.5828 - accuracy: 0.4609
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6079 - accuracy: 0.4688WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.217911). Check your callbacks.
# 4/4 [==============================] - 1s 263ms/step - loss: 1.5971 - accuracy: 0.4609
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6977 - accuracy: 0.3906WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.207938). Check your callbacks.
# 4/4 [==============================] - 1s 245ms/step - loss: 1.6596 - accuracy: 0.4062
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6715 - accuracy: 0.4062WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.141944). Check your callbacks.
# 4/4 [==============================] - 1s 192ms/step - loss: 1.6782 - accuracy: 0.3750
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6845 - accuracy: 0.4531WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.164823). Check your callbacks.
# 4/4 [==============================] - 1s 242ms/step - loss: 1.7346 - accuracy: 0.3750
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6275 - accuracy: 0.3594WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.230343). Check your callbacks.
# 4/4 [==============================] - 1s 245ms/step - loss: 1.6498 - accuracy: 0.3672
# 2/4 [==============>...............] - ETA: 0s - loss: 1.5611 - accuracy: 0.5469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.234576). Check your callbacks.
# 4/4 [==============================] - 1s 256ms/step - loss: 1.5414 - accuracy: 0.5078
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6206 - accuracy: 0.4531WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.343384). Check your callbacks.
# 4/4 [==============================] - 1s 348ms/step - loss: 1.6454 - accuracy: 0.4297
# 2/4 [==============>...............] - ETA: 0s - loss: 1.4941 - accuracy: 0.5156WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.238453). Check your callbacks.
# 4/4 [==============================] - 1s 249ms/step - loss: 1.5413 - accuracy: 0.4453
# 2/4 [==============>...............] - ETA: 0s - loss: 1.6941 - accuracy: 0.3750WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.184411). Check your callbacks.
# 4/4 [==============================] - 1s 201ms/step - loss: 1.6186 - accuracy: 0.4688
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2020-06-18 19:20:12.542118: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# Traceback (most recent call last):
#   File "c:\programdata\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\programdata\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\Scripts\tensorboard.exe\__main__.py", line 7, in <module>
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\main.py", line 75, in run_main
#     app.run(tensorboard.main, flags_parser=tensorboard.configure)
#   File "c:\programdata\anaconda3\lib\site-packages\absl\app.py", line 299, in run
#     _run_main(main, args)
#   File "c:\programdata\anaconda3\lib\site-packages\absl\app.py", line 250, in _run_main
#     sys.exit(main(argv))
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\program.py", line 289, in main
#     return runner(self.flags) or 0
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\program.py", line 305, in _run_serve_subcommand
#     server = self._make_server()
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\program.py", line 409, in _make_server
#     self.flags, self.plugin_loaders, self.assets_zip_provider
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\backend\application.py", line 147, in standard_tensorboard_wsgi
#     flags, plugin_loaders, data_provider, assets_zip_provider, multiplexer
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\backend\application.py", line 226, in TensorBoardWSGIApp
#     tbplugins, flags.path_prefix, data_provider, experimental_plugins
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\backend\application.py", line 299, in __init__
#     "Duplicate plugins for name %s" % plugin.plugin_name
# ValueError: Duplicate plugins for name projector

# %%
#net.load_weights("5.8_nin_weights.h5")

x_test, y_test = nin.get_batch_test(2000)
net.evaluate(x_test, y_test, verbose=2)
## 因为算力有限，的迭代次数少，训练效果差
# Out:
# 63/63 - 1s - loss: 1.5181 - accuracy: 0.3855
# [1.5180714130401611, 0.3855000138282776]

# %%
# %load_ext tensorboard
# %tensorboard --logdir log/min1
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2020-06-18 22:14:48.870569: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# Traceback (most recent call last):
#   File "c:\programdata\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\programdata\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\Scripts\tensorboard.exe\__main__.py", line 7, in <module>
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\main.py", line 75, in run_main
#     app.run(tensorboard.main, flags_parser=tensorboard.configure)
#   File "c:\programdata\anaconda3\lib\site-packages\absl\app.py", line 299, in run
#     _run_main(main, args)
#   File "c:\programdata\anaconda3\lib\site-packages\absl\app.py", line 250, in _run_main
#     sys.exit(main(argv))
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\program.py", line 289, in main
#     return runner(self.flags) or 0
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\program.py", line 305, in _run_serve_subcommand
#     server = self._make_server()
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\program.py", line 409, in _make_server
#     self.flags, self.plugin_loaders, self.assets_zip_provider
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\backend\application.py", line 184, in standard_tensorboard_wsgi
#     flags, plugin_loaders, data_provider, assets_zip_provider, multiplexer
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\backend\application.py", line 265, in TensorBoardWSGIApp
#     tbplugins, flags.path_prefix, data_provider, experimental_plugins
#   File "c:\programdata\anaconda3\lib\site-packages\tensorboard\backend\application.py", line 338, in __init__
#     "Duplicate plugins for name %s" % plugin.plugin_name
# ValueError: Duplicate plugins for name projector
